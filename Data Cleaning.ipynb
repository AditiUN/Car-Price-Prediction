# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('scraped cars24 data.csv')
cars.head()
# Out:
#                                      Name Transmission  KM_Driven  \
# 0  2020 Maruti New  Wagon-R LXI CNG 1.0 L       MANUAL  20,724 km
# 1         2017 Maruti Celerio ZXI OPT AMT    AUTOMATIC  87,848 km
# 2           2010 Hyundai i10 ERA 1.1 IRDE       MANUAL  60,476 km
# 3                2013 Maruti Alto 800 LXI       MANUAL  40,700 km
# 4         2021 Mahindra XUV 3OO W8 (O) AT          NaN   4,022 km
#
#       Fuel_Type      Owner  Registration            EMI  \
# 0  Petrol + CNG  1st Owner         DL-1C  ?11,626/month
# 1        Petrol  1st Owner  TS-08-x-xxxx   ?8,893/month
# 2        Petrol  2nd Owner         KL-40   ?3,775/month
# 3        Petrol  1st Owner  TN-12-x-xxxx   ?5,019/month
# 4        Petrol  1st Owner         MH-12  ?22,781/month
#
#                    Sales    Year                      Types       City
# 0   Fixed Price?5,94,699  20-Sep                        CNG  New Delhi
# 1     ?4,65,799?4,54,899  17-Jan                     Maruti  Hyderabad
# 2     ?2,29,099?1,93,099  10-Aug                        NaN      Kochi
# 3   Fixed Price?2,56,699  13-Jul  Cars from 2 lakh - 5 lakh    Chennai
# 4  Fixed Price?12,13,099  21-Dec                   Mahindra       Pune

# %% [markdown]
# ## Data Cleaning

# %%
# striping '?', '/month' and replacing ','

cars['EMI'] = cars['EMI'].astype(str).str.strip('?').str.strip('/month')
cars['EMI'] = cars['EMI'].str.replace(",", "")

# %%
# striping km and replacing ','

cars['KM_Driven'] = cars['KM_Driven'].astype(str).str.strip('km')
cars['KM_Driven'] = cars['KM_Driven'].str.replace(",", "")

# %%
# correcting Sales column

new1 = cars["Sales"].str.split("?", expand = True)
cars["Sales"]= new1[1]
cars["Discount"]= new1[2]
cars["Sales"] = cars["Sales"].str.replace(",", "")
cars['Discount'] = cars['Discount'].str.replace(",", "")

# %%
# extracting year and types column 
new2 = cars["Name"].str.split(" ", expand = True)
new2
# Out:
#         0           1        2     3        4     5       6     7     8   \
# 0     2020      Maruti      New        Wagon-R   LXI     CNG   1.0     L
# 1     2017      Maruti  Celerio   ZXI      OPT   AMT    None  None  None
# 2     2010     Hyundai      i10   ERA      1.1  IRDE    None  None  None
# 3     2013      Maruti     Alto   800      LXI  None    None  None  None
# 4     2021    Mahindra      XUV   3OO       W8   (O)      AT  None  None
# ...    ...         ...      ...   ...      ...   ...     ...   ...   ...
# 2040  2021     Renault   Duster   RXZ      CVT   1.3   TURBO  None  None
# 2041  2022         KIA   SELTOS   GTX     PLUS  1.4G     DCT  DUAL  TONE
# 2042  2020  Volkswagen     Polo  HIGH     LINE  PLUS     1.0  None  None
# 2043  2020     Renault   TRIBER   1.0      RXZ  None    None  None  None
# 2044  2018     Hyundai   Tucson   New      2WD    MT  PETROL  None  None
#
#         9     10
# 0     None  None
# 1     None  None
# 2     None  None
# 3     None  None
# 4     None  None
# ...    ...   ...
# 2040  None  None
# 2041  None  None
# 2042  None  None
# 2043  None  None
# 2044  None  None
#
# [2045 rows x 11 columns]

# %%
cars["Year"]= new2[0]
cars['Types']=new2[1]

# %%
cars['Name'] = new2[new2.columns[1:]].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
cars['Name']
# Out:
# 0            Maruti New  Wagon-R LXI CNG 1.0 L
# 1                   Maruti Celerio ZXI OPT AMT
# 2                     Hyundai i10 ERA 1.1 IRDE
# 3                          Maruti Alto 800 LXI
# 4                   Mahindra XUV 3OO W8 (O) AT
#                          ...
# 2040          Renault Duster RXZ CVT 1.3 TURBO
# 2041    KIA SELTOS GTX PLUS 1.4G DCT DUAL TONE
# 2042        Volkswagen Polo HIGH LINE PLUS 1.0
# 2043                    Renault TRIBER 1.0 RXZ
# 2044          Hyundai Tucson New 2WD MT PETROL
# Name: Name, Length: 2045, dtype: object

# %%
cars
# Out:
#                                         Name Transmission KM_Driven  \
# 0          Maruti New  Wagon-R LXI CNG 1.0 L       MANUAL    20724
# 1                 Maruti Celerio ZXI OPT AMT    AUTOMATIC    87848
# 2                   Hyundai i10 ERA 1.1 IRDE       MANUAL    60476
# 3                        Maruti Alto 800 LXI       MANUAL    40700
# 4                 Mahindra XUV 3OO W8 (O) AT          NaN     4022
# ...                                      ...          ...       ...
# 2040        Renault Duster RXZ CVT 1.3 TURBO    AUTOMATIC    10821
# 2041  KIA SELTOS GTX PLUS 1.4G DCT DUAL TONE          NaN     1114
# 2042      Volkswagen Polo HIGH LINE PLUS 1.0       MANUAL    17595
# 2043                  Renault TRIBER 1.0 RXZ       MANUAL    33419
# 2044        Hyundai Tucson New 2WD MT PETROL       MANUAL    86670
#
#          Fuel_Type      Owner  Registration    EMI    Sales  Year       Types  \
# 0     Petrol + CNG  1st Owner         DL-1C  11626   594699  2020      Maruti
# 1           Petrol  1st Owner  TS-08-x-xxxx   8893   465799  2017      Maruti
# 2           Petrol  2nd Owner         KL-40   3775   229099  2010     Hyundai
# 3           Petrol  1st Owner  TN-12-x-xxxx   5019   256699  2013      Maruti
# 4           Petrol  1st Owner         MH-12  22781  1213099  2021    Mahindra
# ...            ...        ...           ...    ...      ...   ...         ...
# 2040        Petrol  1st Owner         DL-7C  27010  1548199  2021     Renault
# 2041        Petrol  1st Owner  KA-01-x-xxxx  39614  2234399  2022         KIA
# 2042        Petrol  1st Owner         MH-14  15337   784519  2020  Volkswagen
# 2043        Petrol  1st Owner  TS-08-x-xxxx  12563   647599  2020     Renault
# 2044        Petrol  2nd Owner         UP-14  27569  1583199  2018     Hyundai
#
#            City Discount
# 0     New Delhi     None
# 1     Hyderabad   454899
# 2         Kochi   193099
# 3       Chennai     None
# 4          Pune     None
# ...         ...      ...
# 2040  New Delhi  1438299
# 2041  Bangalore  2109499
# 2042       Pune     None
# 2043  Hyderabad   642599
# 2044  New Delhi  1468099
#
# [2045 rows x 12 columns]

# %%
# renaming Sales as Price
cars.rename(columns = {'Sales':'Price'}, inplace = True)

# %%
cars.to_csv('carsEDA.csv')

# %% [markdown]
# ## EDA

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2045 entries, 0 to 2044
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2045 non-null   object
#  1   Transmission  1872 non-null   object
#  2   KM_Driven     2045 non-null   object
#  3   Fuel_Type     2045 non-null   object
#  4   Owner         2045 non-null   object
#  5   Registration  2045 non-null   object
#  6   EMI           2045 non-null   object
#  7   Price         2043 non-null   object
#  8   Year          2045 non-null   object
#  9   Types         2045 non-null   object
#  10  City          2045 non-null   object
#  11  Discount      1261 non-null   object
# dtypes: object(12)
# memory usage: 191.8+ KB

# %%
cars.isna().sum()
# Out:
# Name              0
# Transmission    173
# KM_Driven         0
# Fuel_Type         0
# Owner             0
# Registration      0
# EMI               0
# Price             2
# Year              0
# Types             0
# City              0
# Discount        784
# dtype: int64

# %%
# fill Discount's NaN values with Price

cars['Discount'].fillna(cars['Price'], inplace = True)

# %%
# fill Transmission NaN value with mode 

cars['Transmission'].fillna('Manual', inplace = True)

# %%
cars1 = cars.drop_duplicates()

# %%
# drop remaining NaN values 

cars1.dropna(inplace=True)
# Out:
# C:\Users\Ashwini\AppData\Local\Temp\ipykernel_1272\2354350636.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars1.dropna(inplace=True)

# %%
# converting object type to integer type

cars1['KM_Driven'] = cars1['KM_Driven'].astype('int64')
cars1['EMI'] = cars1['EMI'].astype('int64')
cars1['Price'] = cars1['Price'].astype('int64')
cars1['Discount'] = cars1['Discount'].astype('int64')
cars1['Year'] = cars1['Year'].astype('int64')
# Out:
# C:\Users\Ashwini\AppData\Local\Temp\ipykernel_1272\958950550.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars1['KM_Driven'] = cars1['KM_Driven'].astype('int64')
# C:\Users\Ashwini\AppData\Local\Temp\ipykernel_1272\958950550.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars1['EMI'] = cars1['EMI'].astype('int64')
# C:\Users\Ashwini\AppData\Local\Temp\ipykernel_1272\958950550.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars1['Price'] = cars1['Price'].astype('int64')
# C:\Users\Ashwini\AppData\Local\Temp\ipykernel_1272\958950550.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars1['Discount'] = cars1['Discount'].astype('int64')
# C:\Users\Ashwini\AppData\Local\Temp\ipykernel_1272\958950550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars1['Year'] = cars1['Year'].astype('int64')

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2031 entries, 0 to 2044
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2031 non-null   object
#  1   Transmission  2031 non-null   object
#  2   KM_Driven     2031 non-null   int64
#  3   Fuel_Type     2031 non-null   object
#  4   Owner         2031 non-null   object
#  5   Registration  2031 non-null   object
#  6   EMI           2031 non-null   int64
#  7   Price         2031 non-null   int64
#  8   Year          2031 non-null   int64
#  9   Types         2031 non-null   object
#  10  City          2031 non-null   object
#  11  Discount      2031 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 206.3+ KB

# %%
cars1.isna().sum()
# Out:
# Name            0
# Transmission    0
# KM_Driven       0
# Fuel_Type       0
# Owner           0
# Registration    0
# EMI             0
# Price           0
# Year            0
# Types           0
# City            0
# Discount        0
# dtype: int64

# %%
cars.describe()
# Out:
#                     Name Transmission KM_Driven Fuel_Type      Owner  \
# count               2045         2045      2045      2045       2045
# unique               677            3      1996         3          4
# top     Maruti Swift VXI       MANUAL     9215     Petrol  1st Owner
# freq                  44         1524         3      1528       1580
#
#         Registration    EMI   Price  Year   Types       City Discount
# count           2045   2045    2043  2045    2045       2045     2043
# unique           274   1855    1818    15      21         13     1858
# top     UP-32-x-xxxx  13435  687199  2019  Maruti  New Delhi   687199
# freq             107      6       7   341     443        238        6

# %%
cars1.shape
# Out:
# (2031, 12)

# %%
pd.value_counts(cars['Types'])
# Out:
# Maruti        443
# Hyundai       349
# Honda         216
# Tata          181
# Renault       163
# Ford          143
# Mahindra      130
# Volkswagen    121
# Toyota        108
# KIA            90
# MG             41
# Nissan         17
# Skoda          15
# Jeep           13
# Datsun          7
# Mercedes        3
# SKODA           1
# Jaguar          1
# MARUTI          1
# Fiat            1
# Chevrolet       1
# Name: Types, dtype: int64

# %%
pd.value_counts(cars['Fuel_Type'])
# Out:
# Petrol          1528
# Diesel           411
# Petrol + CNG     106
# Name: Fuel_Type, dtype: int64

# %%
pd.value_counts(cars['Transmission'])
# Out:
# MANUAL       1524
# AUTOMATIC     348
# Manual        173
# Name: Transmission, dtype: int64

# %%
pd.value_counts(cars1['Owner'])
# Out:
# 1st Owner    1568
# 2nd Owner     425
# 3rd Owner      37
# 4th Owner       1
# Name: Owner, dtype: int64
